# %%
import pandas as pd

# %%
df_sin_full = pd.read_csv('checkpoint_paysim_Dlatent_I_sin_full/metrics.csv')
df = pd.read_csv('checkpoint_paysim_Dlatent_I/metrics.csv')

# %%
df_solo_full = df.loc[df['method'] == 'Full-data']
df_solo_full.head(10)
# Out:
#          model     method  cv_balanced  cv_macro_f1  cv_weighted_f1  \
# 0  naive_bayes  Full-data        0.783        0.364           0.722
# 1       logreg  Full-data        0.718        0.792           0.999
# 2          knn  Full-data        0.847        0.902           1.000
# 3          xgb  Full-data        0.925        0.942           1.000
# 4           rf  Full-data        0.988        0.598           0.994
# 5          mlp  Full-data        0.855        0.908           1.000
#
#    cv_accuracy  cv_balanced_std  cv_macro_f1_std  cv_weighted_f1_std  \
# 0        0.567            0.000            0.001               0.001
# 1        0.999            0.015            0.013               0.000
# 2        1.000            0.003            0.003               0.000
# 3        1.000            0.004            0.004               0.000
# 4        0.990            0.002            0.003               0.000
# 5        1.000            0.013            0.004               0.000
#
# ...

# %%
df_sin_full_complete = pd.concat([df_solo_full, df_sin_full], axis=0)
df_sin_full_complete.head(20)
# Out:
#           model     method  cv_balanced  cv_macro_f1  cv_weighted_f1  \
# 0   naive_bayes  Full-data        0.783        0.364           0.722
# 1        logreg  Full-data        0.718        0.792           0.999
# 2           knn  Full-data        0.847        0.902           1.000
# 3           xgb  Full-data        0.925        0.942           1.000
# 4            rf  Full-data        0.988        0.598           0.994
# 5           mlp  Full-data        0.855        0.908           1.000
# 0   naive_bayes     random        0.800        0.760           0.760
# 1        logreg     random        0.800        0.733           0.733
# 2           knn     random        0.750        0.680           0.680
# 3           xgb     random        0.900        0.867           0.867
# 4            rf     random        0.750        0.707           0.707
# 5           mlp     random        0.700        0.627           0.627
# 6   naive_bayes    k-means        0.700        0.600           0.600
# ...

# %%
df_sin_full_complete.to_csv('checkpoint_paysim_Dlatent_I/metrics.csv',index=False)
