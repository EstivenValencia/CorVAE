# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Análisis del dataset shoppers

# %%
df_shoppers = pd.read_csv('data/shoppers/dataset.csv')

# %% [markdown]
# # Análisis del dataset Adult

# %% [markdown]
# # Análisis del dataset default
